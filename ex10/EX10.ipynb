# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory (NSL) </span>
# ## <span style="color:blue">  Numerical exercises 10</span>

# %% [markdown]
# ### Exercise 10.1
#
# Parallelize with MPI libraries your Genetic Algorithm code in order to solve the TSP by performing a *Genetic Search* with (up to) 10 **parallel GA searches of the optimal path**:
# each node should perform an independent GA search, the so-called *Continent*, **but** every $N_{migr}$ generations the *Continents* should exchange their best individuals randomly.

# %% [markdown]
# ### Exercise 10.2
#
# Apply your code to the TSP problem for 50 american state-capitals longitude and latitude coordinates in the *American_capitals.dat* file.
#
# Do you improve with respect using one single Continent?
#
# Do you improve with respect using (up to) 10 independent Continents?

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math


fig, [[ax_0, ax_1, ax_2], [ax_3, ax_4, ax_5], [ax_6, ax_7, ax_8]] = plt.subplots(3, 3, figsize=(22,17))


for i in range(9):
    f, fm = np.loadtxt("ex10.1/Averages" + str(i) + ".out", usecols=(0,1), unpack='true')
    x = range(0, f.size)
    globals()['ax_'+str(i)].plot(x, f)
    globals()['ax_'+str(i)].set_title("Processore n°" + str(i))
    globals()['ax_'+str(i)].set_xlabel('generazione')
    globals()['ax_'+str(i)].set_ylabel('Distance')
    print ("Distanza minore: ", np.min(f))
# Out:
# Distanza minore:  273.53
# Distanza minore:  273.53
# Distanza minore:  273.53
# Distanza minore:  273.53
# Distanza minore:  273.53
# Distanza minore:  273.53
# Distanza minore:  273.53
# Distanza minore:  273.53
# Distanza minore:  273.53

# %%
fig, [[ax_0, ax_1, ax_2], [ax_3, ax_4, ax_5], [ax_6, ax_7, ax_8]] = plt.subplots(3, 3, figsize=(22,17))


for i in range(9):
    f, fm = np.loadtxt("ex10.1/Cities" + str(i) + ".out", usecols=(0,1), unpack='true')
    globals()['ax_'+str(i)].plot(f, fm, marker="o")
    globals()['ax_'+str(i)].set_title("Processore n°" + str(i))

# %% [markdown]
# La simulazione è stata fatta su 9 processori: ogni processore ha fatto 500 passi con migrazioni ogni 50 e una popolazione complessiva di 3000 elementi.
# Dai grafici si evince che tutti i processori arrivano allo stesso percorso, quindi le migrazioni hanno l'effetto di far prevalere il percorso più efficiente anche negli altri continenti.<br>
# Le probabilità di mutazione sono state abbassate perchè le migrazioni forniscono mutazioni in più. Le probabilità di mutazione usate sono: <br>
# p_perm = 0.45;<br>
# p_inv = 0.1;<br>
# p_shift = 0.45;<br>
# p_perm_bl = 0.2;<br>
# La possibilità che un elemento venisse mutato più di una volta con la stessa mutazione è rimasta.
# Avendo abbassato le probabilità di mutazione si è abbassato anche il tempo di convergenza, infatti adesso dopo 300 passi tutti i processori sono a convergenza.
