# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math


f, fm = np.loadtxt("ex10.1/Averages1.out", usecols=(0,1), unpack='true')
x = range(0, f.size)

fig, [ax0, ax1] = plt.subplots(1, 2, figsize=(22,10))

ax0.plot(x, f, label="Passo uniforme")
ax0.set_title("Integrale per $\mu=0.814217$ e $\sigma=0.668011$")

ax1.plot(x, fm, label="Passo uniforme")
ax1.set_title("Integrale per $\mu=0.814217$ e $\sigma=0.668011$")

print ("Distanza minore: ", np.min(f))
# Out:
# Distanza minore:  78.716

# %%
fig, [[ax_0, ax_1, ax_2], [ax_3, ax_4, ax_5], [ax_6, ax_7, ax_8]] = plt.subplots(3, 3, figsize=(22,17))


for i in range(9):
    f, fm = np.loadtxt("ex10.1/Averages" + str(i) + ".out", usecols=(0,1), unpack='true')
    x = range(0, f.size)
    globals()['ax_'+str(i)].plot(x, f)
    globals()['ax_'+str(i)].set_title("Processore n°" + str(i))
    globals()['ax_'+str(i)].set_xlabel('generazione')
    globals()['ax_'+str(i)].set_ylabel('Distance')

# %%
fig, [[ax_0, ax_1, ax_2], [ax_3, ax_4, ax_5], [ax_6, ax_7, ax_8]] = plt.subplots(3, 3, figsize=(22,17))


for i in range(9):
    f, fm = np.loadtxt("ex10.1/Cities" + str(i) + ".out", usecols=(0,1), unpack='true')
    globals()['ax_'+str(i)].plot(x, f)
    globals()['ax_'+str(i)].set_title("Processore n°" + str(i))
    globals()['ax_'+str(i)].set_xlabel('generazione')
    globals()['ax_'+str(i)].set_ylabel('Distance')
