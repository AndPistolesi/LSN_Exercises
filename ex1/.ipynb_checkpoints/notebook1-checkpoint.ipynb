# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory (NSL) </span>
#
# ## IMPORTANT: Guidelines for a proper conduct of the exercises
# 1. you should create code that is correct, simple, well organized, indented, commented, which uses self-explanatory names for variables and that is numerically efficient.
# 2. I expect a responsible interaction during the exercises: the questions should be more related to the conduction of the exercises and to the meaning of the results obtained than to the computational problems. Bugs are usual in coding; for this reason, sooner or later, one should learn to deal with them by oneself ... if you'll be able to, it will be your main achievement in this Laboratory!
#
# ## <span style="color:blue">  Numerical exercises 1</span>

# %% [markdown]
# ### Exercise 01.1
# - Test the Pseudo-Random Number generator downloaded from the NSL Ariel web site by estimating:

# %% [markdown]
# 1. $\langle r \rangle = \int_0^1 r dr = 1/2$. <font color="red">Make a picture of the estimation of $\langle r \rangle$ and its uncertainty (which corresponds to Standard Deviation of the mean for the estimation of $\langle r \rangle$) with a large number of *throws* $M$ (e.g. $M\ge 10^4$) as a function of the number of blocks, $N$</font> (see below: Computing statistical uncertainties).

# %% [markdown]
# 2. $\sigma^2 = \int_0^1 (r-1/2)^2 dr = 1/12$. <font color="red">Make a picture of the estimation of $\sigma^2$ and its uncertainty (which corresponds to Standard Deviation of the mean for the estimation of $\langle (r-1/2)^2 \rangle$) with a large number of *throws* $M$ (e.g. $M\ge 10^4$) as a function of the number of blocks, $N$</font> (see below: Computing statistical uncertainties).

# %% [markdown]
# 3. Divide $[0,1]$ into $M$ identical sub-intervals and implement the $\chi^2$ test. Obviously, the number of expected events observed in each sub-interval after $n$ *throws*, according to a uniform distribution, is $np = n\times 1/M= n/M$. Fix $M=10^2$ and use for $n$ the first $10^4$ pseudo-random numbers, then the successive $10^4$ pseudo-random numbers, and so on ... 100 times. <font color="red">Plot $\chi^2_j$ for $j=1, ..., 100$</font>. In this case the chi-square statistic is:
# $$\chi^2 = \sum_{i=1}^M \frac{\left( n_i - n/M \right)^2}{n/M}$$
# We should expect on average that $(n_i - n/M)^2 \simeq n/M$ and thus $\chi^2 \simeq 100$, i.e. the number of sub-intervals.
# A larger value of $\chi^2$ indicates that the hypothesis ($n_i$ are drawn from a uniform distribution) is rather unlikely ... <font color="red">but before judging</font>, you could compare the histogram of the values obtained for $\chi^2_j$ with the true probability distribution (see: <a href="https://en.wikipedia.org/wiki/Chi-squared_distribution">this Wikipedia link</a>).

# %% [markdown]
# ##### $\langle r \rangle = \int_0^1 r dr = 1/2$

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

x, f, error = np.loadtxt("ex1.1/Integral.dat", usecols=(0,1,2), unpack='true')

plt.errorbar(x,f,yerr=error)
plt.axhline(y = 0.5, color='r', linestyle='-')
plt.xlabel('x')
plt.ylabel('f(x)')

plt.show()

# %% [markdown]
# Il grafico mostra l'evoluzione del valore medio di una variabile casuale r estratta uniformemente tra 0 e 1. Risulta evidente dal grafico che all'aumentare del numero eventi, il valor medio si avvicina sempre di più al valore atteso 0.5, con il quale è assolutamente compatibile considerando l'incertezza statistica. L'incertezza statistica riportata nel grafico è stata calcolata con il metodo delle medie a blocchi. Il numero di estrazioni totali è 50000, sono state suddivise in 100 blocchi.

# %% [markdown]
# ###### $\sigma^2 = \int_0^1 (r-1/2)^2 dr = 1/12$

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

x, f, error = np.loadtxt("./ex1.1/Integral.dat", usecols=(0,3,4), unpack='true')


plt.errorbar(x,f,yerr=error)
plt.axhline(y=1/12, color='r', linestyle='-')
plt.xlabel('x')
plt.ylabel('f(x)')

plt.show()

# %% [markdown]
# Il grafico mostra l'evoluzione della varianza sul valore $r-\frac{1}{2}$ con r estratta uniformemente tra 0 e 1. L'incertezza statistica riportata nel grafico è stata calcolata con il metodo delle medie a blocchi. Il numero di estrazioni totali è 50000, sono state suddivise in 100 blocchi.

# %% [markdown]
# Calcolo del $\chi^2$

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

x, f= np.loadtxt("./ex1.1/Interval.dat", usecols=(0,1), unpack='true')

plt.plot(x,f)

plt.xlabel('x')
plt.ylabel('$\chi^2$(x)')

plt.show()

# %% [markdown]
# Il grafico riporta cento risultati del test statistico del $\chi^2$. Ogni valore è stato calcolato estraendo 10000 numeri pseudo casuali. I valori oscillano attorno ad un valor medio molto vicino a 100, che è il valore che mi aspetterei di trovare. La deviazione standard di questa distribuzione è 10; quindi il $\chi^2$ è compatibile con 100 e quindi il generatore genera effettivamente numeri distribuiti uniformemente.

# %% [markdown]
# ### Exercise 01.2
# - Extend Pseudo-Random Number generator downloaded from the NSL Ariel web site and check the Central Limit Theorem:

# %% [markdown]
# 1. <font color="red">Add two probability distributions</font> by using the **method of the inversion of the cumulative distribution** to sample from a **generic** <font color="red">exponential distribution</font>, $p(x) = \lambda \exp(-\lambda x)$, $x\in [0;+\infty]$ (see <a href="https://en.wikipedia.org/wiki/Exponential_distribution">this Wikipedia link</a>), and a **generic** <font color="red">Cauchy-Lorentz distribution</font> $p(x)=\frac{1}{\pi}\frac{\Gamma}{(x-\mu)^2+\Gamma^2}$, $x\in [-\infty;+\infty]$ (see <a href="https://en.wikipedia.org/wiki/Cauchy_distribution">this Wikipedia link</a>).
# 2. <font color="red">Make 3 pictures</font> with the histograms obtained filling them with $10^4$ realizations of $S_N = \frac{1}{N}\sum_{i=1}^N x_i$ (for $N=1, 2, 10, 100$), being $x_i$ a random variable sampled throwing a *standard* dice (fig.1), an *exponential* dice (fig.2, use $\lambda=1$) and a *Lorentzian* dice (fig.3, use $\mu=0$ and $\Gamma=1$).
#
# Note tha you can try to fit the case $N=100$ with a Gaussian for standard and exponential dices, whereas you should use a Cauchy-Lorentz distribution for the last case.

# %% [markdown]
# ## Distribuzione Uniforme

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(1) # Fixing random seed for reproducibility

std1, std2, std10, std100 = np.loadtxt("ex1.2/mid.dat", usecols=(2,5, 8, 11), delimiter=' , ', unpack='true')



fig, [ax0, ax1, ax2, ax3] = plt.subplots(1, 4, figsize=(22,8))

n_bins = 50
ax0.set_xlabel('x')
ax0.set_ylabel('p(x)')
ax0.set_title('std n=1')
n, bins, patches = ax0.hist(std1, n_bins, density=True, facecolor='g')
ax0.grid(True)

ax1.set_xlabel('x')
ax1.set_ylabel('p(x)')
ax1.set_title('std n=2')
n, bins, patches = ax1.hist(std2, n_bins, density=True, facecolor='g')
ax1.grid(True)


ax2.set_xlabel('x')
ax2.set_ylabel('p(x)')
ax2.set_title('std n=10')
n, bins, patches = ax2.hist(std10, n_bins, density=True, facecolor='g')
ax2.grid(True)


ax3.set_xlabel('x')
ax3.set_ylabel('p(x)')
ax3.set_title('std n=100')
n, bins, patches = ax3.hist(std100, n_bins, density=True, facecolor='g')
ax3.grid(True)

# %% [markdown]
# ## Distribuzione Esponenziale

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(1) # Fixing random seed for reproducibility

std1, std2, std10, std100 = np.loadtxt("ex1.2/mid.dat", usecols=(2,5, 8, 11), delimiter=' , ', unpack='true')



fig, [ax0, ax1, ax2, ax3] = plt.subplots(1, 4, figsize=(22,8))

n_bins = 50
ax0.set_xlabel('x')
ax0.set_ylabel('p(x)')
ax0.set_title('exp n=1')
n, bins, patches = ax0.hist(exp1, n_bins, density=True, facecolor='g')
ax0.grid(True)

ax1.set_xlabel('x')
ax1.set_ylabel('p(x)')
ax1.set_title('exp n=2')
n, bins, patches = ax1.hist(exp2, n_bins, density=True, facecolor='g')
ax1.grid(True)


ax2.set_xlabel('x')
ax2.set_ylabel('p(x)')
ax2.set_title('exp n=10')
n, bins, patches = ax2.hist(exp10, n_bins, density=True, facecolor='g')
ax2.grid(True)


ax3.set_xlabel('x')
ax3.set_ylabel('p(x)')
ax3.set_title('exp n=100')
n, bins, patches = ax3.hist(exp100, n_bins, density=True, facecolor='g')
ax3.grid(True)

# %% [markdown]
# ## Distribuzione Lorentziana

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(1) # Fixing random seed for reproducibility

Lorentz1, Lorentz2, Lorentz10, Lorentz100 = np.loadtxt("ex1.2/mid.dat", usecols=(1,4,7,10), delimiter=' , ', unpack='true')
fig, [ax0, ax1, ax2, ax3] = plt.subplots(1, 4, figsize=(22,8))

n_bins = 50
ax0.set_xlabel('x')
ax0.set_ylabel('p(x)')
ax0.set_title('Lorentz n=1')
n, bins, patches = ax0.hist(Lorentz1, n_bins, density=True, facecolor='g', range=(-10,10))
ax0.grid(True)

ax1.set_xlabel('x')
ax1.set_ylabel('p(x)')
ax1.set_title('Lorentz n=2')
n, bins, patches = ax1.hist(Lorentz2, n_bins, density=True, facecolor='g', range=(-10,10))
ax1.grid(True)


ax2.set_xlabel('x')
ax2.set_ylabel('p(x)')
ax2.set_title('Lorentz n=10')
n, bins, patches = ax2.hist(Lorentz10, n_bins, density=True, facecolor='g', range=(-10,10))
ax2.grid(True)


ax3.set_xlabel('x')
ax3.set_ylabel('p(x)')
ax3.set_title('Lorentz n=100')
n, bins, patches = ax3.hist(Lorentz100, n_bins, density=True, facecolor='g', range=(-10,10))
ax3.grid(True)

# %% [markdown]
# Cercando una verifica del teorama del lilmite centrale si trova che per le ditribuzioni esponenziale e uniforme il teorema sembra verificato, mentre per la distribuzione lorentziana sembra non valere.
# Questo perchèla distribuzione Lorentziana non ha varianza finita e quindi per lei non vale il teorema del limite centrale. Infatti una Lorentziana per N crescente tende sempre a una Lorentziana

# %% [markdown]
# ### Exercise 01.3
# - **Simulate** the Buffon’s experiment (see LSN_Lecture_00, supplementary material):  A needle of length $L$ is thrown at random onto a horizontal plane ruled with straight lines a distance $d$ (must be $d > L$, but do not use $d\gg L$ otherwise $P\ll 1$) apart. The probability $P$ that the needle will intersect one of these lines is: $P = 2L/\pi d$. This could be used to evaluate $\pi$ from throws of the needle: if the needle is thrown down $N_{thr}$ times and is observed to land on a line $N_{hit}$ of those times, we can make an estimate of $\pi$ from
# $$\pi = \frac{2L}{Pd} = \lim_{N_{thr} \to \infty}\frac{2LN_{thr}}{N_{hit}d}$$
# <font color="red">Make a picture of the estimation of $\pi$ and its uncertainty (Standard Deviation of the mean) with a large number of *throws* $M$ as a function of the number of blocks, $N$</font> (see below: Computing statistical uncertainties). If possible, do not use $\pi$ to evaluate $\pi$.

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

x, f, error = np.loadtxt("./ex1.3/mid.dat", usecols=(0,1,2), unpack='true')


plt.errorbar(x,f,yerr=error)
plt.axhline(y=math.pi, color='r', linestyle='-')
plt.xlabel('x')
plt.ylabel('f(x)')

plt.show()

# %% [markdown]
# La figura rappresenta la stima progressiva del valore di $\pi$. La stima in ciascun blocco si è ottenuta lanciando la sbarretta 100 volte. Nel codice non è stato usato il valore di noto a priori, per campionare un angolo in modo uniforme ho generato un punto uniformemente in un cerchio e $\theta = arctg(\frac{y}{x})$.
